# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as pt
import cv2

# %%
#"C:\Users\user\OneDrive\Documents\Pictures\ge.jpg"

# %%
data=cv2.imread(r"C:\Users\user\OneDrive\Documents\Pictures\ge.jpg")

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (449, 1280, 3)

# %%
pt.imshow(data)

# %%
cdata=data[:400,:]

# %%
pt.imshow(cdata)

# %%
import pandas as pd

# %%
saldata=pd.read_csv("https://raw.githubusercontent.com/pramodini18/Salary-prediction/refs/heads/master/Salary_Data.csv")

# %%
saldata
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
pt.plot(saldata.YearsExperience,saldata.Salary)

# %%
from sklearn.model_selection import train_test_split

# %%
X=saldata [ 'Years Experience']

y=saldata['Salary']

X_train, X_test, y_train, y_test=train_test_split(X, y, random_state=30)

# %%
X_train

# %%
usa=pd.read_csv("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 usa=pd.read_csv("")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as pt
from sklearn.cluster import KMeans

# %%
data=[2,3,4,10,11,12,20,25,30]

# %%
data-pd.a=Data
